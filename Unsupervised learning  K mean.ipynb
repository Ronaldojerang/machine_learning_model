# %% [markdown]
# # Unsupervised learning K mean

# %%
import pandas as pd 
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv('/Users/ronaldojerang/Desktop/oliefolder/bank.csv')

# %%
df
# Out:
#        age          job  marital            education  default housing loan  \
# 0       56    housemaid  married             basic.4y       no      no   no
# 1       57     services  married          high.school  unknown      no   no
# 2       37     services  married          high.school       no     yes   no
# 3       40       admin.  married             basic.6y       no      no   no
# 4       56     services  married          high.school       no      no  yes
# ...    ...          ...      ...                  ...      ...     ...  ...
# 41183   73      retired  married  professional.course       no     yes   no
# 41184   46  blue-collar  married  professional.course       no      no   no
# 41185   56      retired  married    university.degree       no     yes   no
# 41186   44   technician  married  professional.course       no      no   no
# 41187   74      retired  married  professional.course       no     yes   no
#
# ...

# %%
df.isnull().sum()
# Out:
# age               0
# job               0
# marital           0
# education         0
# default           0
# housing           0
# loan              0
# contact           0
# month             0
# day_of_week       0
# duration          0
# campaign          0
# pdays             0
# previous          0
# poutcome          0
# emp.var.rate      0
# cons.price.idx    0
# cons.conf.idx     0
# euribor3m         0
# nr.employed       0
# subscribed        0
# dtype: int64

# %%
X = pd.get_dummies(df)

# %%
X # since it is unSupervised learning we require  only the input data
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       56       261         1    999         0           1.1          93.994
# 1       57       149         1    999         0           1.1          93.994
# 2       37       226         1    999         0           1.1          93.994
# 3       40       151         1    999         0           1.1          93.994
# 4       56       307         1    999         0           1.1          93.994
# ...    ...       ...       ...    ...       ...           ...             ...
# 41183   73       334         1    999         0          -1.1          94.767
# 41184   46       383         1    999         0          -1.1          94.767
# 41185   56       189         2    999         0          -1.1          94.767
# 41186   44       442         1    999         0          -1.1          94.767
# 41187   74       239         3    999         1          -1.1          94.767
#
# ...

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler= StandardScaler()

# %%
scaled = scaler.fit_transform(X)

# %%
X
# Out:
#        age  duration  campaign  pdays  previous  emp.var.rate  cons.price.idx  \
# 0       56       261         1    999         0           1.1          93.994
# 1       57       149         1    999         0           1.1          93.994
# 2       37       226         1    999         0           1.1          93.994
# 3       40       151         1    999         0           1.1          93.994
# 4       56       307         1    999         0           1.1          93.994
# ...    ...       ...       ...    ...       ...           ...             ...
# 41183   73       334         1    999         0          -1.1          94.767
# 41184   46       383         1    999         0          -1.1          94.767
# 41185   56       189         2    999         0          -1.1          94.767
# 41186   44       442         1    999         0          -1.1          94.767
# 41187   74       239         3    999         1          -1.1          94.767
#
# ...

# %%
X = pd.DataFrame(data = scaled , columns = X.columns)

# %%
X
# Out:
#             age  duration  campaign     pdays  previous  emp.var.rate  \
# 0      1.533034  0.010471 -0.565922  0.195414 -0.349494      0.648092
# 1      1.628993 -0.421501 -0.565922  0.195414 -0.349494      0.648092
# 2     -0.290186 -0.124520 -0.565922  0.195414 -0.349494      0.648092
# 3     -0.002309 -0.413787 -0.565922  0.195414 -0.349494      0.648092
# 4      1.533034  0.187888 -0.565922  0.195414 -0.349494      0.648092
# ...         ...       ...       ...       ...       ...           ...
# 41183  3.164336  0.292025 -0.565922  0.195414 -0.349494     -0.752343
# 41184  0.573445  0.481012 -0.565922  0.195414 -0.349494     -0.752343
# 41185  1.533034 -0.267225 -0.204909  0.195414 -0.349494     -0.752343
# 41186  0.381527  0.708569 -0.565922  0.195414 -0.349494     -0.752343
# 41187  3.260295 -0.074380  0.156105  0.195414  1.671136     -0.752343
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed  ...  \
# ...

# %%
from sklearn.cluster import KMeans

# %%
kmc = KMeans(n_clusters = 2)# here we are putting the number of cluster manually

# %%
kmc
# Out:
# KMeans(n_clusters=2)

# %%
kmc.fit(X)
# Out:
# KMeans(n_clusters=2)

# %%
X
# Out:
#             age  duration  campaign     pdays  previous  emp.var.rate  \
# 0      1.533034  0.010471 -0.565922  0.195414 -0.349494      0.648092
# 1      1.628993 -0.421501 -0.565922  0.195414 -0.349494      0.648092
# 2     -0.290186 -0.124520 -0.565922  0.195414 -0.349494      0.648092
# 3     -0.002309 -0.413787 -0.565922  0.195414 -0.349494      0.648092
# 4      1.533034  0.187888 -0.565922  0.195414 -0.349494      0.648092
# ...         ...       ...       ...       ...       ...           ...
# 41183  3.164336  0.292025 -0.565922  0.195414 -0.349494     -0.752343
# 41184  0.573445  0.481012 -0.565922  0.195414 -0.349494     -0.752343
# 41185  1.533034 -0.267225 -0.204909  0.195414 -0.349494     -0.752343
# 41186  0.381527  0.708569 -0.565922  0.195414 -0.349494     -0.752343
# 41187  3.260295 -0.074380  0.156105  0.195414  1.671136     -0.752343
#
#        cons.price.idx  cons.conf.idx  euribor3m  nr.employed  ...  \
# ...

# %%
kmc.predict(X)
# Out:
# array([0, 0, 0, ..., 1, 1, 1], dtype=int32)

# %%
# now SSD i.e sum of squared distances , it when the distance and the cluster will remain ideal for the model
# mean it wont change highly
ssd= []

# %%
for k in range(2,10):
    kmc = KMeans(n_clusters = k)
    kmc.fit(X)
    ssd.append(kmc.inertia_)

# %%
ssd
# Out:
# [2469792.367302056,
#  2370416.304999374,
#  2271503.763015325,
#  2204983.492101611,
#  2179016.9089314244,
#  2080719.6334367087,
#  2058008.2464233737,
#  1986760.930392367]

# %%
sns.scatterplot(x = range(2,10), y = ssd)
# Out:
# <AxesSubplot:>

# %%
# here at 5 n 6 the change is not much mean it is the one we should use to predict
kmc = KMeans(n_clusters = 5)

# %%
kmc.fit(X)
# Out:
# KMeans(n_clusters=5)

# %%
kmc.predict(X)
# Out:
# array([2, 2, 2, ..., 4, 3, 4], dtype=int32)
