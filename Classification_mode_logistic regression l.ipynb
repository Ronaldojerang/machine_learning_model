# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df= pd.read_csv("/Users/ronaldojerang/Desktop/oliefolder/car.csv")

# %%
df
# Out:
#     Salary  Expenses carornot
# 0    25000     20000       No
# 1    75000     40000      Yes
# 2    34000     30000       No
# 3    29000     25000       No
# 4    31000     20000       No
# 5    33000     31000       No
# 6    52000     26000      Yes
# 7    49000     30000      Yes
# 8    20000     15000       No
# 9    15000     12000       No
# 10   55000     38000      Yes
# 11   49000     33000      Yes
# 12   53000     30000      Yes
# 13   21000     17000       No
# 14   45271     13537      Yes
# 15   75074     18261      Yes
# 16   82582     37160      Yes
# 17   22233     17393       No
# 18   79000     40730      Yes
# 19   28500     22800       No
# 20   19000     18000       No
# 21   74000     20000      Yes
# 22  137000     43000      Yes
# 23   57000     16000      Yes
# 24   76000     44000      Yes
# 25   90000     58000      Yes
# 26   84000     27000      Yes
# 27  150000     28000      Yes
# 28   49000     33000       No
# 29   80000     31000      Yes
# ...

# %%
sns.scatterplot(data = df , x = 'Salary',y = 'Expenses',hue = 'carornot')
# Out:
# <AxesSubplot:xlabel='Salary', ylabel='Expenses'>

# %%
df.isnull().sum()
# Out:
# Salary      0
# Expenses    0
# carornot    0
# dtype: int64

# %%
df2 =pd. get_dummies(df,columns=['carornot'],drop_first = True)

# %%
df2
# Out:
#     Salary  Expenses  carornot_Yes
# 0    25000     20000             0
# 1    75000     40000             1
# 2    34000     30000             0
# 3    29000     25000             0
# 4    31000     20000             0
# 5    33000     31000             0
# 6    52000     26000             1
# 7    49000     30000             1
# 8    20000     15000             0
# 9    15000     12000             0
# 10   55000     38000             1
# 11   49000     33000             1
# 12   53000     30000             1
# 13   21000     17000             0
# 14   45271     13537             1
# 15   75074     18261             1
# 16   82582     37160             1
# 17   22233     17393             0
# 18   79000     40730             1
# 19   28500     22800             0
# 20   19000     18000             0
# 21   74000     20000             1
# 22  137000     43000             1
# 23   57000     16000             1
# 24   76000     44000             1
# 25   90000     58000             1
# ...

# %%
x = df2.drop('carornot_Yes',axis = 1)

# %%
x
# Out:
#     Salary  Expenses
# 0    25000     20000
# 1    75000     40000
# 2    34000     30000
# 3    29000     25000
# 4    31000     20000
# 5    33000     31000
# 6    52000     26000
# 7    49000     30000
# 8    20000     15000
# 9    15000     12000
# 10   55000     38000
# 11   49000     33000
# 12   53000     30000
# 13   21000     17000
# 14   45271     13537
# 15   75074     18261
# 16   82582     37160
# 17   22233     17393
# 18   79000     40730
# 19   28500     22800
# 20   19000     18000
# 21   74000     20000
# 22  137000     43000
# 23   57000     16000
# 24   76000     44000
# 25   90000     58000
# 26   84000     27000
# 27  150000     28000
# 28   49000     33000
# 29   80000     31000
# 30   52000     17000
# 31   86000     51000
# 32  108000     18000
# 33   82000     15000
# 34   25000     20000
# 35   79000     26000
# 36   54000     28000
# 37  135000     29000
# 38   89000     22000
# 39   49000     32000
# 40   44000     41000
# 41   83000     22000
# ...

# %%
y = df2['carornot_Yes']

# %%
y
# Out:
# 0     0
# 1     1
# 2     0
# 3     0
# 4     0
# 5     0
# 6     1
# 7     1
# 8     0
# 9     0
# 10    1
# 11    1
# 12    1
# 13    0
# 14    1
# 15    1
# 16    1
# 17    0
# 18    1
# 19    0
# 20    0
# 21    1
# 22    1
# 23    1
# 24    1
# 25    1
# 26    1
# 27    1
# 28    0
# 29    1
# 30    1
# 31    1
# 32    1
# 33    1
# 34    0
# 35    1
# 36    1
# 37    1
# 38    1
# 39    0
# 40    0
# 41    1
# 42    0
# 43    1
# 44    1
# 45    1
# 46    1
# 47    0
# 48    1
# 49    0
# Name: carornot_Yes, dtype: uint8

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = .2)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
lr.predict([[24,42]])
# Out:
# array([0], dtype=uint8)

# %%
pred = lr.predict(x_test)

# %%
pred
# Out:
# array([1, 1, 1, 0, 1, 0, 0, 1, 0, 1], dtype=uint8)

# %%
print(y_test)
# Out:
# 15    1
# 48    1
# 4     0
# 10    1
# 26    1
# 42    0
# 8     0
# 24    1
# 13    0
# 33    1
# Name: carornot_Yes, dtype: uint8

# %%
from sklearn.metrics import classification_report,plot_confusion_matrix

# %%
plot_confusion_matrix(lr,x_test,y_test) # it wass compute it own result n check with y_test

# %%
print(classification_report(y_test,pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.75      0.75      0.75         4
#            1       0.83      0.83      0.83         6
#
#     accuracy                           0.80        10
#    macro avg       0.79      0.79      0.79        10
# weighted avg       0.80      0.80      0.80        10

# %%
x_test
# Out:
#     Salary  Expenses
# 15   75074     18261
# 48   61000     25000
# 4    31000     20000
# 10   55000     38000
# 26   84000     27000
# 42   23000     23000
# 8    20000     15000
# 24   76000     44000
# 13   21000     17000
# 33   82000     15000

# %%
y_test
# Out:
# 15    1
# 48    1
# 4     0
# 10    1
# 26    1
# 42    0
# 8     0
# 24    1
# 13    0
# 33    1
# Name: carornot_Yes, dtype: uint8

# %%
pred
# Out:
# array([1, 1, 1, 0, 1, 0, 0, 1, 0, 1], dtype=uint8)
